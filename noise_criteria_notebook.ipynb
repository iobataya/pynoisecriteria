# %% [markdown]
# # Noise Criteria analysis

# %%
# Reloading module for debugging.
import NC_criteria
import importlib
importlib.reload(NC_criteria)
#

from NC_criteria import NC_table

# %%
# Instantiate with filename
nc = NC_table(loadfile="test_data.csv")

# %%
nc.calculate_levels()
# Out:
#            63    125    250    500   1000   2000   4000   8000
# ------------------------------------------------------------------------
#    Data  55.0   50.0   45.0   53.0   40.0   30.0   20.0   10.0
# ------------------------------------------------------------------------
#   NC-15  47.0*  36.0*  29.0*  22.0*  17.0*  14.0*  12.0*  11.0
#   NC-20  51.0*  40.0*  33.0*  26.0*  22.0*  19.0*  17.0*  16.0
#   NC-25  54.0*  44.0*  37.0*  31.0*  27.0*  24.0*  22.0   21.0
#   NC-30  57.0   48.0*  41.0*  35.0*  31.0*  29.0*  28.0   27.0
#   NC-35  60.0   52.0   45.0*  40.0*  36.0*  34.0   33.0   32.0
#   NC-40  64.0   56.0   50.0   45.0*  41.0   39.0   38.0   37.0
#   NC-45  67.0   60.0   54.0   49.0*  46.0   44.0   43.0   42.0
#   NC-50  71.0   64.0   58.0   54.0   51.0   49.0   48.0   47.0
#   NC-55  74.0   67.0   62.0   58.0   56.0   54.0   53.0   52.0
#   NC-60  77.0   71.0   67.0   63.0   61.0   59.0   58.0   57.0
# None
# ...

# %% [markdown]
# ## Internal variables and matrices

# %%
print(nc.octave_bands)
print(nc.data)
# Out:
# [  63  125  250  500 1000 2000 4000 8000]
# [55. 50. 45. 53. 40. 30. 20. 10.]

# %%
nc.level_mat
# Out:
# array([[47., 36., 29., 22., 17., 14., 12., 11.],
#        [51., 40., 33., 26., 22., 19., 17., 16.],
#        [54., 44., 37., 31., 27., 24., 22., 21.],
#        [57., 48., 41., 35., 31., 29., 28., 27.],
#        [60., 52., 45., 40., 36., 34., 33., 32.],
#        [64., 56., 50., 45., 41., 39., 38., 37.],
#        [67., 60., 54., 49., 46., 44., 43., 42.],
#        [71., 64., 58., 54., 51., 49., 48., 47.],
#        [74., 67., 62., 58., 56., 54., 53., 52.],
#        [77., 71., 67., 63., 61., 59., 58., 57.]])

# %%
nc.NC_gt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 nc.NC_gt
#
# AttributeError: 'NC_table' object has no attribute 'NC_gt'
